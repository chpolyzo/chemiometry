# %%
import numpy as np
import pandas as pd
from sklearn.decomposition import PCA
from sklearn.preprocessing import StandardScaler
import matplotlib.pyplot as plt
import seaborn as sns
data = pd.read_csv('PinotNoir.csv')
X = data.to_numpy()
# Calculate the correlation matrix using NumPy
corr_matrix = np.corrcoef(data.T)  # Transpose to treat columns as variables
# Display the correlation matrix
#print("Correlation Matrix:")
#print(corr_matrix)

# Create a heatmap of the correlation matrix
#plt.figure(figsize=(15, 15))
#sns.heatmap(corr_matrix, annot=True, cmap='coolwarm', fmt='.2f', linewidths=0.5)

# Display the plot
#plt.title("Correlation Matrix Heatmap")
#plt.show();

# Step 1: Standardize the data
scaler = StandardScaler()
X_scaled = scaler.fit_transform(X);

# Step 2: Calculate the covariance matrix
cov_matrix = np.cov(X_scaled.T);  # Transpose to get features in columns

# Step 3: Calculate the eigenvalues and eigenvectors
eigenvalues, eigenvectors = np.linalg.eig(cov_matrix)

# Display results
#print("Eigenvalues of the covariance matrix:", eigenvalues)
#print("Eigenvectors of the covariance matrix:");
#print(eigenvectors);

# %%
# read data into a dataframe
data = pd.read_csv('PinotNoir.csv')
# pass to numpy
X = data.to_numpy()
# Calculate the correlation matrix using numpy
corr_matrix = np.corrcoef(data.T)
# Create a heatmap of the correlation matrix

fig, ax = plt.subplots(figsize = (10, 10 ))

im = sns.heatmap(corr_matrix, xticklabels = data.columns, annot=True, yticklabels = data.columns, ax=ax)

fig.tight_layout()
plt.show()

# %%
eigenvalues_df = pd.DataFrame(eigenvalues, index = data.columns, columns = ['Covarriance'] )

# %%
eigenvectors_df = pd.DataFrame(eigenvectors, index = data.columns, columns = ['PC ' + str(i) for i in range(len(eigenvectors))] )

# %%
eigenvalues_df
# Out:
#        Covarriance
# Cd        4.721474
# Mo        2.895997
# Mn        2.337862
# Ni        2.081071
# Cu        1.508548
# Al        1.020225
# Ba        0.893539
# Cr        0.676170
# Sr        0.617351
# Pb        0.509194
# B         0.405682
# Mg        0.281012
# Si        0.216203
# Na        0.140202
# Ca        0.089611
# P         0.017765
# K         0.035126
# Aroma     0.052968

# %%
def color_negative(v, color):
    return f"color: {color};" if abs(v) > 0.4 else None

eigenvectors_df.style.map(color_negative, color="red")
# Out:
# <style type="text/css">
# #T_2d162_row0_col7, #T_2d162_row1_col1, #T_2d162_row1_col15, #T_2d162_row2_col2, #T_2d162_row2_col10, #T_2d162_row3_col6, #T_2d162_row4_col6, #T_2d162_row5_col5, #T_2d162_row5_col10, #T_2d162_row6_col7, #T_2d162_row6_col12, #T_2d162_row7_col4, #T_2d162_row7_col13, #T_2d162_row8_col15, #T_2d162_row8_col17, #T_2d162_row9_col1, #T_2d162_row9_col15, #T_2d162_row10_col3, #T_2d162_row10_col10, #T_2d162_row11_col9, #T_2d162_row12_col9, #T_2d162_row13_col4, #T_2d162_row13_col13, #T_2d162_row14_col11, #T_2d162_row14_col16, #T_2d162_row15_col8, #T_2d162_row16_col12, #T_2d162_row16_col16, #T_2d162_row17_col7, #T_2d162_row17_col12, #T_2d162_row17_col14 {
#   color: red;
# }
# </style>
# <table id="T_2d162">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_2d162_level0_col0" class="col_heading level0 col0" >PC 0</th>
#       <th id="T_2d162_level0_col1" class="col_heading level0 col1" >PC 1</th>
#       <th id="T_2d162_level0_col2" class="col_heading level0 col2" >PC 2</th>
#       <th id="T_2d162_level0_col3" class="col_heading level0 col3" >PC 3</th>
#       <th id="T_2d162_level0_col4" class="col_heading level0 col4" >PC 4</th>
#       <th id="T_2d162_level0_col5" class="col_heading level0 col5" >PC 5</th>
#       <th id="T_2d162_level0_col6" class="col_heading level0 col6" >PC 6</th>
#       <th id="T_2d162_level0_col7" class="col_heading level0 col7" >PC 7</th>
#       <th id="T_2d162_level0_col8" class="col_heading level0 col8" >PC 8</th>
#       <th id="T_2d162_level0_col9" class="col_heading level0 col9" >PC 9</th>
#       <th id="T_2d162_level0_col10" class="col_heading level0 col10" >PC 10</th>
#       <th id="T_2d162_level0_col11" class="col_heading level0 col11" >PC 11</th>
#       <th id="T_2d162_level0_col12" class="col_heading level0 col12" >PC 12</th>
#       <th id="T_2d162_level0_col13" class="col_heading level0 col13" >PC 13</th>
#       <th id="T_2d162_level0_col14" class="col_heading level0 col14" >PC 14</th>
#       <th id="T_2d162_level0_col15" class="col_heading level0 col15" >PC 15</th>
#       <th id="T_2d162_level0_col16" class="col_heading level0 col16" >PC 16</th>
#       <th id="T_2d162_level0_col17" class="col_heading level0 col17" >PC 17</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_2d162_level0_row0" class="row_heading level0 row0" >Cd</th>
#       <td id="T_2d162_row0_col0" class="data row0 col0" >0.060838</td>
#       <td id="T_2d162_row0_col1" class="data row0 col1" >0.293277</td>
#       <td id="T_2d162_row0_col2" class="data row0 col2" >-0.327331</td>
#       <td id="T_2d162_row0_col3" class="data row0 col3" >0.154120</td>
#       <td id="T_2d162_row0_col4" class="data row0 col4" >-0.325597</td>
#       <td id="T_2d162_row0_col5" class="data row0 col5" >0.285317</td>
#       <td id="T_2d162_row0_col6" class="data row0 col6" >0.183529</td>
#       <td id="T_2d162_row0_col7" class="data row0 col7" >-0.404067</td>
#       <td id="T_2d162_row0_col8" class="data row0 col8" >0.086999</td>
#       <td id="T_2d162_row0_col9" class="data row0 col9" >0.001137</td>
#       <td id="T_2d162_row0_col10" class="data row0 col10" >-0.084904</td>
#       <td id="T_2d162_row0_col11" class="data row0 col11" >0.338318</td>
#       <td id="T_2d162_row0_col12" class="data row0 col12" >-0.278794</td>
#       <td id="T_2d162_row0_col13" class="data row0 col13" >0.304842</td>
#       <td id="T_2d162_row0_col14" class="data row0 col14" >-0.300864</td>
#       <td id="T_2d162_row0_col15" class="data row0 col15" >0.057333</td>
#       <td id="T_2d162_row0_col16" class="data row0 col16" >0.032357</td>
#       <td id="T_2d162_row0_col17" class="data row0 col17" >-0.016483</td>
#     </tr>
#     <tr>
#       <th id="T_2d162_level0_row1" class="row_heading level0 row1" >Mo</th>
#       <td id="T_2d162_row1_col0" class="data row1 col0" >-0.093109</td>
#       <td id="T_2d162_row1_col1" class="data row1 col1" >0.521095</td>
#       <td id="T_2d162_row1_col2" class="data row1 col2" >-0.125519</td>
#       <td id="T_2d162_row1_col3" class="data row1 col3" >-0.201445</td>
#       <td id="T_2d162_row1_col4" class="data row1 col4" >0.098393</td>
#       <td id="T_2d162_row1_col5" class="data row1 col5" >0.109663</td>
#       <td id="T_2d162_row1_col6" class="data row1 col6" >0.002833</td>
#       <td id="T_2d162_row1_col7" class="data row1 col7" >0.177019</td>
#       <td id="T_2d162_row1_col8" class="data row1 col8" >-0.047601</td>
#       <td id="T_2d162_row1_col9" class="data row1 col9" >0.004435</td>
#       <td id="T_2d162_row1_col10" class="data row1 col10" >0.039398</td>
#       <td id="T_2d162_row1_col11" class="data row1 col11" >-0.133682</td>
#       <td id="T_2d162_row1_col12" class="data row1 col12" >0.147394</td>
#       <td id="T_2d162_row1_col13" class="data row1 col13" >0.060356</td>
# Aroma  0.455582  0.142183  0.073542 -0.069202 -0.114496 -0.404961 -0.246148
#
#           PC 14     PC 15     PC 16     PC 17
# Cd    -0.300864  0.057333  0.032357 -0.016483
# Mo     0.186485  0.571393  0.208190 -0.398395
# Mn    -0.276293  0.026106 -0.119835  0.172330
# Ni    -0.101414 -0.002656  0.110586  0.114102
# Cu    -0.115568 -0.034485  0.098072 -0.060741
# Al    -0.122807 -0.005584  0.115594  0.001452
# Ba     0.294177  0.204026 -0.395585  0.050439
# Cr     0.097415 -0.046100 -0.296100 -0.040538
# Sr    -0.085788 -0.430505  0.118454 -0.710087
# Pb     0.245797 -0.605951  0.158614  0.311593
# B      0.348536 -0.160593 -0.059630 -0.129425
# Mg    -0.267922  0.074837  0.153595  0.275547
# Si    -0.318949  0.035864  0.131831 -0.029844
# Na    -0.194413  0.034220 -0.101494  0.133721
# Ca    -0.139611 -0.075226 -0.537303 -0.023412
# P     -0.165411  0.090507 -0.137755  0.046132
# K      0.088948  0.081272  0.505105  0.170097
# Aroma -0.456390 -0.133218 -0.071123 -0.214574

# %%
vars(data.columns)
# Out:
# {'_data': array(['Cd', 'Mo', 'Mn', 'Ni', 'Cu', 'Al', 'Ba', 'Cr', 'Sr', 'Pb', 'B',
#         'Mg', 'Si', 'Na', 'Ca', 'P', 'K', 'Aroma'], dtype=object),
#  '_name': None,
#  '_cache': {},
#  '_id': <object at 0x20f60cc4260>,
#  '_references': <pandas._libs.internals.BlockValuesRefs at 0x20f59f4ec50>}

# %%
vars(data.columns)['_data'][0]
# Out:
# 'Cd'

# %%
# Plotting the scree plot
plt.figure(figsize=(8, 6))
plt.plot(range(1, len(eigenvalues) + 1), eigenvalues, marker='o', linestyle='--', color='b')

# Add labels and title
plt.title("Scree Plot of Eigenvalues")
plt.xlabel("Principal Component Index")
plt.ylabel("Eigenvalue")

# Display the plot
plt.show()

# %%
# Step 1: Calculate the covariance matrix
cov_matrix = np.cov(X.T)

# Step 2: Calculate the eigenvalues and eigenvectors of the covariance matrix
eigenvalues, eigenvectors = np.linalg.eig(cov_matrix)

# Step 3: Visualize the eigenvectors
plt.figure(figsize=(8, 6))

# Plot the data points (optional, for context)
plt.scatter(X[:, 0], X[:, 1], color='blue', label='Data')

# Plot eigenvectors
for i in range(len(eigenvalues)):
    eigenvector = eigenvectors[:, i]
    plt.quiver(0, 0, eigenvector[0], eigenvector[1], angles='xy', scale_units='xy', scale=1, color='red', label=f'Eigenvector {i+1}' if i == 0 else "")

# Add labels and title
plt.xlim(-1, 7)
plt.ylim(-1, 7)
plt.axhline(0, color='black',linewidth=1)
plt.axvline(0, color='black',linewidth=1)
plt.title("Eigenvectors of the Covariance Matrix")
plt.xlabel("Feature 1")
plt.ylabel("Feature 2")
plt.legend()

# Display the plot
plt.show()

# %%
# Step 1: Perform PCA to get the principal components (eigenvectors)
pca = PCA(n_components=2)  # We reduce it to 2D for visualization
X_pca = pca.fit_transform(X)

# Step 2: Visualize the principal components (eigenvectors)
plt.figure(figsize=(8, 6))

# Plot the transformed data points in 2D
plt.scatter(X_pca[:, 0], X_pca[:, 1], color='blue', label='Transformed Data')

# Plot the eigenvectors (principal components) as arrows
for i in range(2):
    eigenvector = pca.components_[i]
    plt.quiver(0, 0, eigenvector[0], eigenvector[1], angles='xy', scale_units='xy', scale=1, color='red', label=f'PC {i+1}' if i == 0 else "")

# Add labels and title
plt.title("PCA: Eigenvectors (Principal Components)")
plt.xlabel("Principal Component 1")
plt.ylabel("Principal Component 2")
plt.legend()

# Display the plot
plt.show()
